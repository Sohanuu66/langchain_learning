# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()
GEMINI_API = os.getenv('GEMINI_API_KEY')

# %%
# Out:
# AIzaSyCLZAooR9jqlBC6EI5O5BzNirOxuHBCo0c
